# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import AgentState

class CustomAgentState(AgentState):
    # User request
    source: str
    destination: str
    date: str
    passengers: int
    budget: int
    latitude: float 
    longitude: float 

    # Preferences
    class_type: str

    # Tool outputs
    train_results: list
    selected_train: str
    fare: int

    origin_sky_id: str
    destination_sky_id: str
    origin_entity_id: str
    destination_entity_id: str

# %%
@tool
def get_nearby_airport(runtime: ToolRuntime):
    """By giving the location of us it will search the nearby airport and return us the airport name and also save the sky id and entity id in state"""
    
    RAPID_API_KEY = os.getenv("RAPID_API_KEY")
    
    latitude = runtime.state.get("latitude")
    longitude = runtime.state.get("longitude")
    
    headers = {
        'x-rapidapi-key': RAPID_API_KEY,
        'x-rapidapi-host': "sky-scrapper.p.rapidapi.com",
        'Content-Type': "application/json"
    }
    
    params = {
    "lat": latitude,
    "lng": longitude,
    "locale": "en-US"
    }
    
    res = requests.get(
            "https://irctc1.p.rapidapi.com/api/v1/flights/getNearByAirports", 
            headers=headers,
            params = params
        )
    
    return res.json()

# %%
@tool
def search_flight(runtime: ToolRuntime):
    """search the flight between source and destination and if source is not given by accessing the user location from state get the nearby airports and search"""
    
    RAPID_API_KEY = os.getenv("RAPID_API_KEY")
    
    headers = {
        'x-rapidapi-key': RAPID_API_KEY,
        'x-rapidapi-host': "sky-scrapper.p.rapidapi.com",
        'Content-Type': "application/json"
    }
    
    params = {
    "originSkyId": runtime.state.get("origin_sky_id"),
    "destinationSkyId": runtime.state.get("destination_sky_id"),
    "originEntityId": runtime.state.get("origin_entity_id"),
    "destinationEntityId": runtime.state.get("destination_entity_id"),
    "adults": runtime.state.get("passengers"),
    "cabinClass": runtime.state.get("class_type"),
    "sortBy": "best",
    "currency": "INR",
    "market": "en-US",
    "countryCode": "IN",
}    
    res = requests.get(
            "https://irctc1.p.rapidapi.com//api/v2/flights/searchFlights", 
            headers=headers,
            params = params
        )
    
    return res.json()

# %%
from langchain.agents import create_agent
#flight searching agent
flight_agent = create_agent(
    model = llm,
    tools=[get_nearby_airport,search_flights],
    state_schema=FlightAgentState,
    system_prompt = """You are a Flight Search Agent.

Your job is to help the user find suitable flights between a source and a destination by using the available tools correctly and in the right order.

## Role
You are a careful, tool-using travel assistant.
You must never guess airport codes, sky IDs, or entity IDs.
You must always use tools to resolve locations and search flights.
You should provide clear, neat, user-friendly flight results with important journey details.

## Available Tool Purposes
1. get_nearby_airport
- Use this tool to find the nearby airport, skyId, and entityId for a location.
- Use it when:
  - the user gives a city/place name and you need airport resolution,
  - the user does not provide a source location but the system/user context contains latitude and longitude,
  - you need nearby airport details for source or destination.

2. search_flight
- Use this tool only after you have:
  - originSkyId
  - destinationSkyId
  - originEntityId
  - destinationEntityId
- Use this tool to search flights between the resolved source and destination.

## Core Rules
- Never invent or assume skyId or entityId.
- Never call search_flight before resolving both source and destination.
- If the source is missing, first use get_nearby_airport with available user/current location context.
- If the destination is missing and cannot be inferred safely, ask the user for it.
- If multiple airport/location matches are returned, choose the best city-level relevant match if confidence is high; otherwise ask the user to confirm.
- Always prefer tool-based facts over model memory.
- If tool output is incomplete or ambiguous, explain the issue clearly and ask for clarification.
- Do not mention internal reasoning, hidden chain-of-thought, or implementation details.
- Keep responses concise but complete.

## Task Flow
Follow this exact order:

1. Understand the request
- Extract:
  - source
  - destination
  - travel date
  - passengers
  - cabin preference if provided
  - budget if provided
- If destination is missing, ask the user for destination before continuing.
- If source is missing, use get_nearby_airport from available current location context.

2. Resolve source airport details
- If source is given as a city/place name, call get_nearby_airport or the location-resolution behavior of that tool to get:
  - originSkyId
  - originEntityId
  - airport/city name
- Save the resolved source details.

3. Resolve destination airport details
- Call get_nearby_airport or the same location-resolution behavior for destination to get:
  - destinationSkyId
  - destinationEntityId
  - airport/city name
- Save the resolved destination details.

4. Search flights
- After both source and destination are resolved, call search_flight with:
  - originSkyId
  - destinationSkyId
  - originEntityId
  - destinationEntityId
  - date
  - passengers
  - cabinClass if available, otherwise economy
- If optional search parameters are not provided, use sensible defaults.

5. Present results
- Return the results in a neat and readable format.
- For each useful flight option, include:
  - airline name
  - flight number if available
  - departure airport and time
  - arrival airport and time
  - total duration
  - number of stops
  - stop/layover details if available
  - cabin class
  - price
  - currency
  - booking/deeplink if available
- Mention the resolved source and destination airport/city names used for the search.
- Highlight the best options such as:
  - cheapest
  - fastest
  - best overall
- If no flights are found, say so clearly and suggest nearby-date or nearby-airport flexibility if relevant.

## Output Format
Always structure the final answer like this:

Resolved Route:
- Source: <resolved source city/airport>
- Destination: <resolved destination city/airport>
- Date: <date>
- Passengers: <count>

Best Flight Options:
1. <option 1>
- Airline:
- Departure:
- Arrival:
- Duration:
- Stops:
- Cabin:
- Price:

Recommendation:
- Briefly mention which option is cheapest, fastest, or best overall.

## Missing Information Policy
- If destination is missing, ask for destination.
- If date is missing, ask for travel date.
- If passenger count is missing, assume 1 only if your system allows defaults; otherwise ask.
- If source is missing, use current location context and get_nearby_airport.
- If location resolution is ambiguous, ask the user to confirm the intended place.

## Safety and Reliability
- Never fabricate flight availability or prices.
- Never pretend a tool returned a result if it did not.
- Never output IDs unless useful for debugging or developer-facing logs.
- Base your answer only on tool outputs and explicit user input.

Your goal is to reliably resolve locations, search flights with the correct IDs, and present the results in a clean travel-friendly format. """
)

# %%
response
# Out:
# {'status': True,
#  'timestamp': 1778325136977,
#  'data': {'current': {'presentation': {'title': 'Vijayawada',
#     'suggestionTitle': 'Vijayawada (VGA)',
#     'subtitle': 'India'},
#    'navigation': {'entityId': '128667161',
#     'entityType': 'AIRPORT',
#     'localizedName': 'Vijayawada',
#     'relevantFlightParams': {'skyId': 'VGA',
#      'entityId': '128667161',
#      'flightPlaceType': 'AIRPORT',
#      'localizedName': 'Vijayawada'},
#     'relevantHotelParams': {'entityId': '27550914',
#      'entityType': 'CITY',
#      'localizedName': 'Vijayawada'}}},
#   'nearby': [{'presentation': {'title': 'Rajahmundry',
#      'suggestionTitle': 'Rajahmundry (RJA)',
#      'subtitle': 'India'},
#     'navigation': {'entityId': '128667748',
#      'entityType': 'AIRPORT',
#      'localizedName': 'Rajahmundry',
#      'relevantFlightParams': {'skyId': 'RJA',
#       'entityId': '128667748',
#       'flightPlaceType': 'AIRPORT',
#       'localizedName': 'Rajahmundry'},
# ...

# %%
from langchain.tools import tool
# import http.client
from langchain.tools import tool, ToolRuntime
import requests

@tool
def search_trains(runtime: ToolRuntime):
    """
    Search trains between two stations source and destination.
    """
    RAPID_API_KEY = os.getenv("RAPID_API_KEY")
    
    source = runtime.state.get("source")
    destination = runtime.state.get("destination")

    url = "https://irctc1.p.rapidapi.com/api/v3/trainBetweenStations"

    headers = {
        "x-rapidapi-key": RAPID_API_KEY,
        "x-rapidapi-host": "irctc1.p.rapidapi.com"
    }

    params = {
        "fromStationCode": source,
        "toStationCode": destination
    }

    response = requests.get(
        url,
        headers=headers,
        params=params
    )

    return response.json()

response = search_trains.invoke()
print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 36
#      32     )
#      33
#      34     return response.json()
#      35
# ---> 36 response = search_trains.invoke()
#      37 print(response)
#      38 # @tool
#      39 # def search_trains(
#
# TypeError: BaseTool.invoke() missing 1 required positional argument: 'input'

# %%
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str):

    """Search the web for information"""

    return tavily_client.search(query)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    "gemini-3-flash-preview",
    model_provider = "google_genai"
)
agent = create_agent(
    model = llm,
    tools=[web_search, search_trains],
    state_schema=CustomAgentState,
    checkpointer=InMemorySaver(),
    system_prompt = """ 
You are an AI Train Travel Assistant.

IMPORTANT RULES:

1. You MUST ALWAYS use the search_trains tool
   to find trains between source and destination.

2. NEVER generate train information from your own knowledge.

3. Before calling the tool:
   - extract source and destination
   - save them into agent state

4. After tool execution:
   - use ONLY tool response data
   - format the response clearly

5. If source or destination is missing:
   ask the user for missing details.

6. Output format:

Train No:
Train Name:
Departure Time:
Arrival Time:
Travel Duration:
Total Coaches:
Classes Available:
Best Locations Between Journey:

7. Never skip tool usage.
8. Never hallucinate train data.
"""
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}
response = agent.invoke(
    {"messages":[HumanMessage("I want to travel from palakollu to tirupati on 30 th may 2026 and we are 4 members and we doesnt require ac and food just travelling under budget of 6000/- rupees you can choose between bus and train")]},
    config
)
response
# Out:
# {'messages': [HumanMessage(content='I want to travel from palakollu to tirupati on 30 th may 2026 and we are 4 members and we doesnt require ac and food just travelling under budget of 6000/- rupees you can choose between bus and train', additional_kwargs={}, response_metadata={}, id='4bf8c391-44c7-4836-8c33-d7e99dfe59e1'),
# ...

# %%
from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='I want to travel from palakollu to tirupati on 30 th may 2026 and we are 4 members and we doesnt require ac and food just travelling under budget of 6000/- rupees you can choose between bus and train', additional_kwargs={}, response_metadata={}, id='701dfe1c-ea09-4577-8ac4-b5fb90e30931'),
# ...

# %%
response = agent.invoke(
    {"messages":[HumanMessage("when i arrive at tirupati")]},
    config
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='I want to travel from palakollu to tirupati on 30 th may 2026 and we are 4 members and we doesnt require ac and food just travelling under budget of 6000/- rupees you can choose between bus and train', additional_kwargs={}, response_metadata={}, id='701dfe1c-ea09-4577-8ac4-b5fb90e30931'),
# ...
